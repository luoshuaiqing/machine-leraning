# %%
import keras
from keras import backend as K
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
# I loaded the data from cifar10, which is the same as what we downloaded so does not matter
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
          'dog', 'frog', 'horse', 'ship', 'truck']

target_label = 2

(x_train, t_train), (x_test, t_test) = cifar10.load_data()

t_target = t_train==target_label
t_target = t_target.reshape(t_target.size)
training_set = x_train[t_target]

t_target_2 = t_test==target_label
t_target_2 = t_target_2.reshape(t_target_2.size)
test_set = x_test[t_target_2]

# %%
print(training_set[21][0][0])
print(training_set.shape)
all_data = np.concatenate((training_set, test_set), axis=0)
# Out:
# [73 98 62]
# (5000, 32, 32, 3)

# %% [markdown]
# (c) Those 6000 images have 6000 × 32 × 32 pixels. Choose at least 10% of the pixels randomly. It is strongly recommended that you choose a large number or all of the pixels. You will have between P = 614400 and P = 6144000 pixels. Each pixel is an RGB vector with three elements.

# %%
print("I chose all the datapoints for question c")
# Out:
# I chose all the datapoints for question c

# %% [markdown]
# (d) Run k-means clustering on the P vectors using k = 4. The centers of the clusters
# will be your main colors. Convert the colored images to k-color images by con-
# verting each pixel’s value to the closest main color in terms of Euclidean distance.
# These are the outputs of your network, whose each pixel falls in one of those k
# 2

# %%
from sklearn.cluster import KMeans
pixels = []
pixels = np.reshape(all_data, (6000 * 32 * 32, 3))
kmeans = KMeans(n_clusters=4, random_state=0).fit(pixels)

# %%
print(kmeans.cluster_centers_,"\n=======================")
import math
index = 0
for pixel in pixels:
    min_dist = 100000000
    min_mean = kmeans.cluster_centers_[0]
    for mean in kmeans.cluster_centers_:
        dist = math.sqrt((pixel[0] - mean[0])**2 + (pixel[1] - mean[1])**2 + (pixel[2] - mean[2])**2)
        min_mean = mean if dist < min_dist else min_mean
        min_dist = dist if dist < min_dist else min_dist
    
    pixels[index] = min_mean
    index += 1
    
# images = np.reshape(pixels, (6000, 32, 32, 3))
# output_images = []
# for image in images:
#     img = Image.fromarray(image, 'RGB')
#     output_images.append(img)

# you can show any image by calling output_images[index].show()
# e.g. output_images[0].show()

_kmeans = kmeans.cluster_centers_.astype(int)
# Out:
# [[108.97036568 108.60691289  82.66458238]
#  [206.53651167 211.77549799 211.39857871]
#  [156.18468173 155.51640472 135.57285659]
#  [ 49.02965771  50.01208333  38.57034319]]
# =======================

# %%
# get training label and test label
new_pixels = []
for pixel in pixels:
    new_pixel = [0, 0, 0, 0]
    index_2 = 0
    for kmean in _kmeans:
        if np.array_equal(kmean, pixel):
            new_pixel[index_2] = 1
            new_pixels.append(new_pixel)
        index_2 += 1

print(new_pixels)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# (e) Use any tool (e.g., openCV or scikit-learn) to obtain grayscale 32 × 32 × 1 images from the original 32 × 32 × 3 images. The grayscale images are inputs of your network.

# %%
from PIL import Image
import numpy as np
from skimage import data
from skimage.color import rgb2gray

grayscale_images = []
for original in all_data:
    grayscale = rgb2gray(original)
    grayscale_images.append(grayscale)
#     fig, axes = plt.subplots(1, 2, figsize=(8, 4))
#     ax = axes.ravel()

#     ax[0].imshow(original)
#     ax[0].set_title("Original")
#     ax[1].imshow(grayscale, cmap=plt.cm.gray)
#     ax[1].set_title("Grayscale")

#     fig.tight_layout()
#     plt.show()

print(np.asarray(grayscale_images).shape)

training_data = np.asarray(grayscale_images[:5000])
testing_data = np.asarray(grayscale_images[5000:])
# Out:
# (6000, 32, 32)
# (1000, 32, 32)

# %% [markdown]
# (f)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten , Dense, Activation,Dropout
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(16,(5,5),activation='relu', 
                                 input_shape=(32,32,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())


model.add(layers.Dense(32*32*4))
model.add(layers.Dense(32*32*4))
model.add(layers.Reshape((32, 32, 4)))
model.add(Activation('softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 32)        12832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              3280896
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 32, 32, 4)         0
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 4)         0
# =================================================================
# Total params: 20,075,456
# Trainable params: 20,075,456
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import to_categorical

train_images = training_data.reshape((5000, 32, 32, 1))
train_images = train_images.astype('float32') / 255

test_images = testing_data.reshape((1000, 32, 32, 1))
test_images = test_images.astype('float32') / 255

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

new_pixels = np.reshape(new_pixels, (6000, 32, 32, 4))
training_labels = new_pixels[:5000]
testing_labels = new_pixels[5000:]

from livelossplot import PlotLossesKeras
# training the data and report the training error and validation error during each epoch
history = model.fit(train_images, training_labels, epochs=5, validation_data=(test_images, testing_labels), callbacks=[PlotLossesKeras()])
# Out:
# Log-loss (cost function):
# training   (min:    1.386, max:    1.386, cur:    1.386)
# validation (min:    1.386, max:    1.386, cur:    1.386)
#
# Accuracy:
# training   (min:    0.280, max:    0.297, cur:    0.297)
# validation (min:    0.291, max:    0.295, cur:    0.295)

# %%
# get the test loss and test accuracy
test_loss, test_acc = model.evaluate(test_images, testing_labels)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
print('Test Error Rate:', 1 - test_acc)

print("\n\n===================================================\n\n")

# get the training loss and training accuracy
train_loss, train_acc = model.evaluate(train_images, training_labels)
print('Train accuracy:', train_acc)
print('Train loss:', train_loss)
print('Train Error Rate:', 1 - train_acc)
# Out:
# 1000/1000 [==============================] - 1s 509us/step
# Test accuracy: 0.2954755859375
# Test loss: 1.3859189662933349
# Test Error Rate: 0.7045244140625
#
#
# ===================================================
#
#
# 5000/5000 [==============================] - 3s 501us/step
# Train accuracy: 0.297006640625
# Train loss: 1.3859066368103028
# Train Error Rate: 0.702993359375

# %%
# visually compare the artificially colored versions of the first 10 images in the test set with the original images.
predictions = model.predict_classes(test_images[:10])
# print(kmeans.cluster_centers_)
pixels = []
for row in predictions:
    for col in row:
        for val in col:
            RGB_val = kmeans.cluster_centers_[val]
            pixels.append(RGB_val)        

    
pixels = np.reshape(pixels, (10, 32, 32, 3))

import matplotlib.pyplot as plt

for i in range(10):    
#     show test result
    plt.imshow(pixels[i].astype(int))
    plt.show()
#     show original result
    plt.imshow(test_set[i])
    plt.show()

# %% [markdown]
# extra credit for k = 16

# %%
import keras
from keras import backend as K
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
# I loaded the data from cifar10, which is the same as what we downloaded so does not matter
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
          'dog', 'frog', 'horse', 'ship', 'truck']

target_label = 2

(x_train, t_train), (x_test, t_test) = cifar10.load_data()

t_target = t_train==target_label
t_target = t_target.reshape(t_target.size)
training_set = x_train[t_target]

t_target_2 = t_test==target_label
t_target_2 = t_target_2.reshape(t_target_2.size)
test_set = x_test[t_target_2]

# %%
print(training_set[21][0][0])
print(training_set.shape)
all_data = np.concatenate((training_set, test_set), axis=0)
# Out:
# [73 98 62]
# (5000, 32, 32, 3)

# %% [markdown]
# (c) Those 6000 images have 6000 × 32 × 32 pixels. Choose at least 10% of the pixels randomly. It is strongly recommended that you choose a large number or all of the pixels. You will have between P = 614400 and P = 6144000 pixels. Each pixel is an RGB vector with three elements.

# %%
print("I chose all the datapoints for question c")
# Out:
# I chose all the datapoints for question c

# %% [markdown]
# (d) Run k-means clustering on the P vectors using k = 4. The centers of the clusters
# will be your main colors. Convert the colored images to k-color images by con-
# verting each pixel’s value to the closest main color in terms of Euclidean distance.
# These are the outputs of your network, whose each pixel falls in one of those k
# 2

# %%
from sklearn.cluster import KMeans
pixels = []
pixels = np.reshape(all_data, (6000 * 32 * 32, 3))
kmeans = KMeans(n_clusters=16, random_state=0).fit(pixels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-63-dc81d5946b19> in <module>
#       2 pixels = []
#       3 pixels = np.reshape(all_data, (6000 * 32 * 32, 3))
# ----> 4 kmeans = KMeans(n_clusters=16, random_state=0).fit(pixels)
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y, sample_weight)
#     970                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     971                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 972                 return_n_iter=True)
#     973         return self
#     974
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     379                 verbose=verbose, precompute_distances=precompute_distances,
#     380                 tol=tol, x_squared_norms=x_squared_norms,
# --> 381                 random_state=random_state)
#     382             # determine if these results are the best so far
#     383             if best_inertia is None or inertia < best_inertia:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/cluster/k_means_.py in _kmeans_single_elkan(X, sample_weight, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     443     centers, labels, n_iter = k_means_elkan(X, checked_sample_weight,
#     444                                             n_clusters, centers, tol=tol,
# --> 445                                             max_iter=max_iter, verbose=verbose)
#     446     if sample_weight is None:
#     447         inertia = np.sum((X - centers[labels]) ** 2, dtype=np.float64)
#
# sklearn/cluster/_k_means_elkan.pyx in sklearn.cluster._k_means_elkan.k_means_elkan()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     163
#     164 # Pairwise distances
# --> 165 def euclidean_distances(X, Y=None, Y_norm_squared=None, squared=False,
#     166                         X_norm_squared=None):
#     167     """
#
# KeyboardInterrupt:

# %%
print(kmeans.cluster_centers_,"\n=======================")
import math
index = 0
for pixel in pixels:
    min_dist = 100000000
    min_mean = kmeans.cluster_centers_[0]
    for mean in kmeans.cluster_centers_:
        dist = math.sqrt((pixel[0] - mean[0])**2 + (pixel[1] - mean[1])**2 + (pixel[2] - mean[2])**2)
        min_mean = mean if dist < min_dist else min_mean
        min_dist = dist if dist < min_dist else min_dist
    
    pixels[index] = min_mean
    index += 1
    
# images = np.reshape(pixels, (6000, 32, 32, 3))
# output_images = []
# for image in images:
#     img = Image.fromarray(image, 'RGB')
#     output_images.append(img)

# you can show any image by calling output_images[index].show()
# e.g. output_images[0].show()

_kmeans = kmeans.cluster_centers_.astype(int)
# Out:
# [[108.97036568 108.60691289  82.66458238]
#  [206.53651167 211.77549799 211.39857871]
#  [156.18468173 155.51640472 135.57285659]
#  [ 49.02965771  50.01208333  38.57034319]]
# =======================

# %%
# get training label and test label
new_pixels = []
for pixel in pixels:
    new_pixel = [0] * 16
    index_2 = 0
    for kmean in _kmeans:
        if np.array_equal(kmean, pixel):
            new_pixel[index_2] = 1
            new_pixels.append(new_pixel)
        index_2 += 1

print(new_pixels)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# (e) Use any tool (e.g., openCV or scikit-learn) to obtain grayscale 32 × 32 × 1 images from the original 32 × 32 × 3 images. The grayscale images are inputs of your network.

# %%
from PIL import Image
import numpy as np
from skimage import data
from skimage.color import rgb2gray

grayscale_images = []
for original in all_data:
    grayscale = rgb2gray(original)
    grayscale_images.append(grayscale)
#     fig, axes = plt.subplots(1, 2, figsize=(8, 4))
#     ax = axes.ravel()

#     ax[0].imshow(original)
#     ax[0].set_title("Original")
#     ax[1].imshow(grayscale, cmap=plt.cm.gray)
#     ax[1].set_title("Grayscale")

#     fig.tight_layout()
#     plt.show()

print(np.asarray(grayscale_images).shape)

training_data = np.asarray(grayscale_images[:5000])
testing_data = np.asarray(grayscale_images[5000:])
# Out:
# (6000, 32, 32)
# (1000, 32, 32)

# %% [markdown]
# (f)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten , Dense, Activation,Dropout
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(16,(5,5),activation='relu', 
                                 input_shape=(32,32,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())


model.add(layers.Dense(32*32*16))
model.add(layers.Dense(32*32*16))
model.add(layers.Reshape((32, 32, 16)))
model.add(Activation('softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 32)        12832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              3280896
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 32, 32, 4)         0
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 4)         0
# =================================================================
# Total params: 20,075,456
# Trainable params: 20,075,456
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import to_categorical

train_images = training_data.reshape((5000, 32, 32, 1))
train_images = train_images.astype('float32') / 255

test_images = testing_data.reshape((1000, 32, 32, 1))
test_images = test_images.astype('float32') / 255

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

new_pixels = np.reshape(new_pixels, (6000, 32, 32, 16))
training_labels = new_pixels[:5000]
testing_labels = new_pixels[5000:]

from livelossplot import PlotLossesKeras
# training the data and report the training error and validation error during each epoch
history = model.fit(train_images, training_labels, epochs=5, validation_data=(test_images, testing_labels), callbacks=[PlotLossesKeras()])
# Out:
# Log-loss (cost function):
# training   (min:    1.386, max:    1.386, cur:    1.386)
# validation (min:    1.386, max:    1.386, cur:    1.386)
#
# Accuracy:
# training   (min:    0.280, max:    0.297, cur:    0.297)
# validation (min:    0.291, max:    0.295, cur:    0.295)

# %%
# get the test loss and test accuracy
test_loss, test_acc = model.evaluate(test_images, testing_labels)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
print('Test Error Rate:', 1 - test_acc)

print("\n\n===================================================\n\n")

# get the training loss and training accuracy
train_loss, train_acc = model.evaluate(train_images, training_labels)
print('Train accuracy:', train_acc)
print('Train loss:', train_loss)
print('Train Error Rate:', 1 - train_acc)
# Out:
# 1000/1000 [==============================] - 1s 509us/step
# Test accuracy: 0.2954755859375
# Test loss: 1.3859189662933349
# Test Error Rate: 0.7045244140625
#
#
# ===================================================
#
#
# 5000/5000 [==============================] - 3s 501us/step
# Train accuracy: 0.297006640625
# Train loss: 1.3859066368103028
# Train Error Rate: 0.702993359375

# %%
# visually compare the artificially colored versions of the first 10 images in the test set with the original images.
predictions = model.predict_classes(test_images[:10])
# print(kmeans.cluster_centers_)
pixels = []
for row in predictions:
    for col in row:
        for val in col:
            RGB_val = kmeans.cluster_centers_[val]
            pixels.append(RGB_val)        

    
pixels = np.reshape(pixels, (10, 32, 32, 3))

import matplotlib.pyplot as plt

for i in range(10):    
#     show test result
    plt.imshow(pixels[i].astype(int))
    plt.show()
#     show original result
    plt.imshow(test_set[i])
    plt.show()

# %%
# extra credit for k = 24
import keras
from keras import backend as K
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
# I loaded the data from cifar10, which is the same as what we downloaded so does not matter
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
          'dog', 'frog', 'horse', 'ship', 'truck']

target_label = 2

(x_train, t_train), (x_test, t_test) = cifar10.load_data()

t_target = t_train==target_label
t_target = t_target.reshape(t_target.size)
training_set = x_train[t_target]

t_target_2 = t_test==target_label
t_target_2 = t_target_2.reshape(t_target_2.size)
test_set = x_test[t_target_2]

# %%
print(training_set[21][0][0])
print(training_set.shape)
all_data = np.concatenate((training_set, test_set), axis=0)
# Out:
# [73 98 62]
# (5000, 32, 32, 3)

# %% [markdown]
# (c) Those 6000 images have 6000 × 32 × 32 pixels. Choose at least 10% of the pixels randomly. It is strongly recommended that you choose a large number or all of the pixels. You will have between P = 614400 and P = 6144000 pixels. Each pixel is an RGB vector with three elements.

# %%
print("I chose all the datapoints for question c")
# Out:
# I chose all the datapoints for question c

# %% [markdown]
# (d) Run k-means clustering on the P vectors using k = 4. The centers of the clusters
# will be your main colors. Convert the colored images to k-color images by con-
# verting each pixel’s value to the closest main color in terms of Euclidean distance.
# These are the outputs of your network, whose each pixel falls in one of those k
# 2

# %%
from sklearn.cluster import KMeans
pixels = []
pixels = np.reshape(all_data, (6000 * 32 * 32, 3))
kmeans = KMeans(n_clusters=24, random_state=0).fit(pixels)

# %%
print(kmeans.cluster_centers_,"\n=======================")
import math
index = 0
for pixel in pixels:
    min_dist = 100000000
    min_mean = kmeans.cluster_centers_[0]
    for mean in kmeans.cluster_centers_:
        dist = math.sqrt((pixel[0] - mean[0])**2 + (pixel[1] - mean[1])**2 + (pixel[2] - mean[2])**2)
        min_mean = mean if dist < min_dist else min_mean
        min_dist = dist if dist < min_dist else min_dist
    
    pixels[index] = min_mean
    index += 1
    
# images = np.reshape(pixels, (6000, 32, 32, 3))
# output_images = []
# for image in images:
#     img = Image.fromarray(image, 'RGB')
#     output_images.append(img)

# you can show any image by calling output_images[index].show()
# e.g. output_images[0].show()

_kmeans = kmeans.cluster_centers_.astype(int)
# Out:
# [[108.97036568 108.60691289  82.66458238]
#  [206.53651167 211.77549799 211.39857871]
#  [156.18468173 155.51640472 135.57285659]
#  [ 49.02965771  50.01208333  38.57034319]]
# =======================

# %%
# get training label and test label
new_pixels = []
for pixel in pixels:
    new_pixel = [0] * 24
    index_2 = 0
    for kmean in _kmeans:
        if np.array_equal(kmean, pixel):
            new_pixel[index_2] = 1
            new_pixels.append(new_pixel)
        index_2 += 1

print(new_pixels)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# (e) Use any tool (e.g., openCV or scikit-learn) to obtain grayscale 32 × 32 × 1 images from the original 32 × 32 × 3 images. The grayscale images are inputs of your network.

# %%
from PIL import Image
import numpy as np
from skimage import data
from skimage.color import rgb2gray

grayscale_images = []
for original in all_data:
    grayscale = rgb2gray(original)
    grayscale_images.append(grayscale)
#     fig, axes = plt.subplots(1, 2, figsize=(8, 4))
#     ax = axes.ravel()

#     ax[0].imshow(original)
#     ax[0].set_title("Original")
#     ax[1].imshow(grayscale, cmap=plt.cm.gray)
#     ax[1].set_title("Grayscale")

#     fig.tight_layout()
#     plt.show()

print(np.asarray(grayscale_images).shape)

training_data = np.asarray(grayscale_images[:5000])
testing_data = np.asarray(grayscale_images[5000:])
# Out:
# (6000, 32, 32)
# (1000, 32, 32)

# %% [markdown]
# (f)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten , Dense, Activation,Dropout
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(16,(5,5),activation='relu', 
                                 input_shape=(32,32,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())


model.add(layers.Dense(32*32*24))
model.add(layers.Dense(32*32*24))
model.add(layers.Reshape((32, 32, 24)))
model.add(Activation('softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 32)        12832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              3280896
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 32, 32, 4)         0
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 4)         0
# =================================================================
# Total params: 20,075,456
# Trainable params: 20,075,456
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import to_categorical

train_images = training_data.reshape((5000, 32, 32, 1))
train_images = train_images.astype('float32') / 255

test_images = testing_data.reshape((1000, 32, 32, 1))
test_images = test_images.astype('float32') / 255

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

new_pixels = np.reshape(new_pixels, (6000, 32, 32, 24))
training_labels = new_pixels[:5000]
testing_labels = new_pixels[5000:]

from livelossplot import PlotLossesKeras
# training the data and report the training error and validation error during each epoch
history = model.fit(train_images, training_labels, epochs=5, validation_data=(test_images, testing_labels), callbacks=[PlotLossesKeras()])
# Out:
# Log-loss (cost function):
# training   (min:    1.386, max:    1.386, cur:    1.386)
# validation (min:    1.386, max:    1.386, cur:    1.386)
#
# Accuracy:
# training   (min:    0.280, max:    0.297, cur:    0.297)
# validation (min:    0.291, max:    0.295, cur:    0.295)

# %%
# get the test loss and test accuracy
test_loss, test_acc = model.evaluate(test_images, testing_labels)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
print('Test Error Rate:', 1 - test_acc)

print("\n\n===================================================\n\n")

# get the training loss and training accuracy
train_loss, train_acc = model.evaluate(train_images, training_labels)
print('Train accuracy:', train_acc)
print('Train loss:', train_loss)
print('Train Error Rate:', 1 - train_acc)
# Out:
# 1000/1000 [==============================] - 1s 509us/step
# Test accuracy: 0.2954755859375
# Test loss: 1.3859189662933349
# Test Error Rate: 0.7045244140625
#
#
# ===================================================
#
#
# 5000/5000 [==============================] - 3s 501us/step
# Train accuracy: 0.297006640625
# Train loss: 1.3859066368103028
# Train Error Rate: 0.702993359375

# %%
# visually compare the artificially colored versions of the first 10 images in the test set with the original images.
predictions = model.predict_classes(test_images[:10])
# print(kmeans.cluster_centers_)
pixels = []
for row in predictions:
    for col in row:
        for val in col:
            RGB_val = kmeans.cluster_centers_[val]
            pixels.append(RGB_val)        

    
pixels = np.reshape(pixels, (10, 32, 32, 3))

import matplotlib.pyplot as plt

for i in range(10):    
#     show test result
    plt.imshow(pixels[i].astype(int))
    plt.show()
#     show original result
    plt.imshow(test_set[i])
    plt.show()

# %%
# extra credit for k = 32
import keras
from keras import backend as K
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
# I loaded the data from cifar10, which is the same as what we downloaded so does not matter
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer',
          'dog', 'frog', 'horse', 'ship', 'truck']

target_label = 2

(x_train, t_train), (x_test, t_test) = cifar10.load_data()

t_target = t_train==target_label
t_target = t_target.reshape(t_target.size)
training_set = x_train[t_target]

t_target_2 = t_test==target_label
t_target_2 = t_target_2.reshape(t_target_2.size)
test_set = x_test[t_target_2]

# %%
print(training_set[21][0][0])
print(training_set.shape)
all_data = np.concatenate((training_set, test_set), axis=0)
# Out:
# [73 98 62]
# (5000, 32, 32, 3)

# %% [markdown]
# (c) Those 6000 images have 6000 × 32 × 32 pixels. Choose at least 10% of the pixels randomly. It is strongly recommended that you choose a large number or all of the pixels. You will have between P = 614400 and P = 6144000 pixels. Each pixel is an RGB vector with three elements.

# %%
print("I chose all the datapoints for question c")
# Out:
# I chose all the datapoints for question c

# %% [markdown]
# (d) Run k-means clustering on the P vectors using k = 4. The centers of the clusters
# will be your main colors. Convert the colored images to k-color images by con-
# verting each pixel’s value to the closest main color in terms of Euclidean distance.
# These are the outputs of your network, whose each pixel falls in one of those k
# 2

# %%
from sklearn.cluster import KMeans
pixels = []
pixels = np.reshape(all_data, (6000 * 32 * 32, 3))
kmeans = KMeans(n_clusters=32, random_state=0).fit(pixels)

# %%
print(kmeans.cluster_centers_,"\n=======================")
import math
index = 0
for pixel in pixels:
    min_dist = 100000000
    min_mean = kmeans.cluster_centers_[0]
    for mean in kmeans.cluster_centers_:
        dist = math.sqrt((pixel[0] - mean[0])**2 + (pixel[1] - mean[1])**2 + (pixel[2] - mean[2])**2)
        min_mean = mean if dist < min_dist else min_mean
        min_dist = dist if dist < min_dist else min_dist
    
    pixels[index] = min_mean
    index += 1
    
# images = np.reshape(pixels, (6000, 32, 32, 3))
# output_images = []
# for image in images:
#     img = Image.fromarray(image, 'RGB')
#     output_images.append(img)

# you can show any image by calling output_images[index].show()
# e.g. output_images[0].show()

_kmeans = kmeans.cluster_centers_.astype(int)
# Out:
# [[108.97036568 108.60691289  82.66458238]
#  [206.53651167 211.77549799 211.39857871]
#  [156.18468173 155.51640472 135.57285659]
#  [ 49.02965771  50.01208333  38.57034319]]
# =======================

# %%
# get training label and test label
new_pixels = []
for pixel in pixels:
    new_pixel = [0] * 32
    index_2 = 0
    for kmean in _kmeans:
        if np.array_equal(kmean, pixel):
            new_pixel[index_2] = 1
            new_pixels.append(new_pixel)
        index_2 += 1

print(new_pixels)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# (e) Use any tool (e.g., openCV or scikit-learn) to obtain grayscale 32 × 32 × 1 images from the original 32 × 32 × 3 images. The grayscale images are inputs of your network.

# %%
from PIL import Image
import numpy as np
from skimage import data
from skimage.color import rgb2gray

grayscale_images = []
for original in all_data:
    grayscale = rgb2gray(original)
    grayscale_images.append(grayscale)
#     fig, axes = plt.subplots(1, 2, figsize=(8, 4))
#     ax = axes.ravel()

#     ax[0].imshow(original)
#     ax[0].set_title("Original")
#     ax[1].imshow(grayscale, cmap=plt.cm.gray)
#     ax[1].set_title("Grayscale")

#     fig.tight_layout()
#     plt.show()

print(np.asarray(grayscale_images).shape)

training_data = np.asarray(grayscale_images[:5000])
testing_data = np.asarray(grayscale_images[5000:])
# Out:
# (6000, 32, 32)
# (1000, 32, 32)

# %% [markdown]
# (f)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten , Dense, Activation,Dropout
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(16,(5,5),activation='relu', 
                                 input_shape=(32,32,1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(32, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Flatten())


model.add(layers.Dense(32*32*32))
model.add(layers.Dense(32*32*32))
model.add(layers.Reshape((32, 32, 32)))
model.add(Activation('softmax'))

model.summary()
# Out:
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Users/luoshuaiqing/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 16)        416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 32)        12832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              3280896
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 32, 32, 4)         0
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 4)         0
# =================================================================
# Total params: 20,075,456
# Trainable params: 20,075,456
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils import to_categorical

train_images = training_data.reshape((5000, 32, 32, 1))
train_images = train_images.astype('float32') / 255

test_images = testing_data.reshape((1000, 32, 32, 1))
test_images = test_images.astype('float32') / 255

model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])

new_pixels = np.reshape(new_pixels, (6000, 32, 32, 32))
training_labels = new_pixels[:5000]
testing_labels = new_pixels[5000:]

from livelossplot import PlotLossesKeras
# training the data and report the training error and validation error during each epoch
history = model.fit(train_images, training_labels, epochs=5, validation_data=(test_images, testing_labels), callbacks=[PlotLossesKeras()])
# Out:
# Log-loss (cost function):
# training   (min:    1.386, max:    1.386, cur:    1.386)
# validation (min:    1.386, max:    1.386, cur:    1.386)
#
# Accuracy:
# training   (min:    0.280, max:    0.297, cur:    0.297)
# validation (min:    0.291, max:    0.295, cur:    0.295)

# %%
# get the test loss and test accuracy
test_loss, test_acc = model.evaluate(test_images, testing_labels)
print('Test accuracy:', test_acc)
print('Test loss:', test_loss)
print('Test Error Rate:', 1 - test_acc)

print("\n\n===================================================\n\n")

# get the training loss and training accuracy
train_loss, train_acc = model.evaluate(train_images, training_labels)
print('Train accuracy:', train_acc)
print('Train loss:', train_loss)
print('Train Error Rate:', 1 - train_acc)
# Out:
# 1000/1000 [==============================] - 1s 509us/step
# Test accuracy: 0.2954755859375
# Test loss: 1.3859189662933349
# Test Error Rate: 0.7045244140625
#
#
# ===================================================
#
#
# 5000/5000 [==============================] - 3s 501us/step
# Train accuracy: 0.297006640625
# Train loss: 1.3859066368103028
# Train Error Rate: 0.702993359375

# %%
# visually compare the artificially colored versions of the first 10 images in the test set with the original images.
predictions = model.predict_classes(test_images[:10])
# print(kmeans.cluster_centers_)
pixels = []
for row in predictions:
    for col in row:
        for val in col:
            RGB_val = kmeans.cluster_centers_[val]
            pixels.append(RGB_val)        

    
pixels = np.reshape(pixels, (10, 32, 32, 3))

import matplotlib.pyplot as plt

for i in range(10):    
#     show test result
    plt.imshow(pixels[i].astype(int))
    plt.show()
#     show original result
    plt.imshow(test_set[i])
    plt.show()
